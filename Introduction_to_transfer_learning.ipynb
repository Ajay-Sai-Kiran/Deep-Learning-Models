# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaysaikiran2208/Deep-Learning-Models/blob/main/Introduction_to_transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Introduction to transfer learning [VGG16]

# %%
from keras.applications.vgg16 import VGG16

# %%
model=VGG16()

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
from keras.preprocessing.image import load_img

# %%
image=load_img('/content/dog.jpg',target_size=(224,224))

# %%
import tensorflow as tf
import tensorflow 

from tensorflow import keras
from keras.layers import Dense

# %%
keras.preprocessing.image.img_to_array
# Out:
# <function tensorflow.python.keras.preprocessing.image.img_to_array>

# %%
image=tf.keras.preprocessing.image.array_to_img(image)

# %%
import numpy as np

# %%
image=np.expand_dims(image,axis=0)
image.shape
# Out:
# (1, 224, 224, 3)

# %%
from keras.applications.vgg16 import preprocess_input

# %%
image=preprocess_input(image)

# %%
pred=model.predict(image)

# %%
pred
# Out:
# array([[4.94791053e-09, 4.63457850e-09, 5.67370861e-08, 2.61209596e-08,
#         9.08361830e-10, 1.57288593e-09, 2.17877549e-10, 2.94758831e-08,
#         2.96822435e-07, 1.09373396e-07, 7.09245063e-09, 1.76762800e-08,
#         2.79997470e-09, 7.37537889e-08, 4.38138237e-09, 3.50572620e-08,
#         5.61246634e-06, 6.33530476e-07, 1.94293966e-06, 2.01273238e-07,
#         2.02222552e-07, 4.34093295e-08, 6.80415368e-08, 2.91833651e-08,
#         9.99090375e-08, 8.03868438e-09, 6.14424689e-09, 4.11404466e-09,
#         1.41283660e-08, 5.84860782e-09, 1.27546667e-08, 8.58625349e-09,
#         5.11708187e-09, 1.86786964e-09, 6.52130927e-09, 1.14734275e-08,
#         1.18427588e-08, 8.07436606e-09, 2.79534285e-09, 9.11538400e-09,
#         1.10266555e-07, 3.55256002e-09, 6.48363052e-09, 3.25224470e-08,
#         1.77354131e-08, 4.58387861e-09, 4.61414409e-08, 1.14412330e-07,
#         1.17675925e-09, 9.06653383e-08, 1.10319087e-08, 2.98257241e-08,
# ...

# %%
from tensorflow.keras.applications.mobilenet import decode_predictions
pred_classes=decode_predictions(pred,top=5)
for i in pred_classes[0]:
  print(i)
# Out:
# ('n02113186', 'Cardigan', 0.43118525)
# ('n02106166', 'Border_collie', 0.3876408)
# ('n02106030', 'collie', 0.08654766)
# ('n02105412', 'kelpie', 0.08387159)
# ('n02110806', 'basenji', 0.0045802575)

# %% [markdown]
# VGG 19

# %%
from keras.applications.vgg19 import VGG19

# %%
model=VGG19()
# Out:
# ...
# 574726144/574710816 [==============================] - 6s 0us/step

# %%
model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
from keras.preprocessing.image import load_img

# %%
image=load_img('/content/dog.jpg',target_size=(224,224))

# %%
import tensorflow as tf
import tensorflow 

from tensorflow import keras
from keras.layers import Dense

# %%
keras.preprocessing.image.img_to_array
# Out:
# <function tensorflow.python.keras.preprocessing.image.img_to_array>

# %%
image=tf.keras.preprocessing.image.array_to_img(image)

# %%
import numpy as np

# %%
image=np.expand_dims(image,axis=0)
image.shape
# Out:
# (1, 224, 224, 3)

# %%
from keras.applications.vgg16 import preprocess_input

# %%
image=preprocess_input(image)

# %%
pred=model.predict(image)

# %%
from tensorflow.keras.applications.mobilenet import decode_predictions
pred_classes=decode_predictions(pred,top=5)
for i in pred_classes[0]:
  print(i)
# Out:
# ('n02113186', 'Cardigan', 0.43118525)
# ('n02106166', 'Border_collie', 0.3876408)
# ('n02106030', 'collie', 0.08654766)
# ('n02105412', 'kelpie', 0.08387159)
# ('n02110806', 'basenji', 0.0045802575)
